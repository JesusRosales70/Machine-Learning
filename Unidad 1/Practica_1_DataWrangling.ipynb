# %% [markdown]
# <a href="https://colab.research.google.com/github/JesusRosales70/Machine-Learning/blob/main/Unidad%201/Practica_1_DataWrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Machine y Deep Learning**
#
# ## **Unidad 1. Introduccion a Machine Learning y Deep Learning**
#
# Práctica 1: **DataWrangling**
#
# ### **Docente:** Dr. Jose Gabriel Rodriguez Rivas
#
# ### **Alumno:** Jesus Armando Rosales Martinez

# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
autos = pd.read_csv("AutosDatosSucios.csv")
autos.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               201 non-null    object
#  19  stroke             201 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         203 non-null    object
#  22  peak-rpm           203 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              201 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %%
autos.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
# 5        sedan          fwd           front        99.8  ...          136
# 6        sedan          fwd           front       105.8  ...          136
# 7        wagon          fwd           front       105.8  ...          136
# 8        sedan          fwd           front       105.8  ...          131
# 9    hatchback          4wd           front        99.5  ...          131
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
# 5         mpfi  3.19     3.4               8.5        110      5500       19
# 6         mpfi  3.19     3.4               8.5        110      5500       19
# 7         mpfi  3.19     3.4               8.5        110      5500       19
# 8         mpfi  3.13     3.4               8.3        140      5500       17
# 9         mpfi  3.13     3.4               7.0        160      5500       16
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
# 5          25  15250
# 6          25  17710
# 7          25  18920
# 8          20  23875
# 9          22      ?
#
# [10 rows x 26 columns]

# %%
autos.replace("?", np.nan, inplace = True)
autos.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
# Contar valores perdidos en la columna normalized-losses
autos["normalized-losses"].isnull().value_counts()
# Out:
# normalized-losses
# False    164
# True      41
# Name: count, dtype: int64

# %%
# Contar valores perdidos en todas las columnas
autos.isna().sum().sort_values()
# Out:
# symboling             0
# make                  0
# fuel-type             0
# aspiration            0
# drive-wheels          0
# body-style            0
# wheel-base            0
# engine-location       0
# height                0
# curb-weight           0
# length                0
# width                 0
# engine-type           0
# num-of-cylinders      0
# fuel-system           0
# engine-size           0
# highway-mpg           0
# compression-ratio     0
# city-mpg              0
# num-of-doors          2
# peak-rpm              2
# horsepower            2
# bore                  4
# stroke                4
# price                 4
# normalized-losses    41
# dtype: int64

# %% [markdown]
# **ELIMINACION DE DATOS O REMPLAZAR LOS DATOS**

# %%
avg_norm_loss = autos["normalized-losses"].astype("float").mean(axis=0)
print("Promedio de normalized-losses:", avg_norm_loss)
# Out:
# Promedio de normalized-losses: 122.0

# %%
autos["normalized-losses"].replace(np.nan, avg_norm_loss, inplace=True)
# Out:
# /tmp/ipykernel_5728/850475528.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   autos["normalized-losses"].replace(np.nan, avg_norm_loss, inplace=True)

# %%
avg_bore = autos['bore'].astype('float').mean(axis=0)
print("Promedio de bore:",avg_bore)
# Out:
# Promedio de bore: 3.3297512437810943

# %%
autos["bore"].replace(np.nan, avg_bore, inplace=True)
# Out:
# /tmp/ipykernel_5728/327159589.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   autos["bore"].replace(np.nan, avg_bore, inplace=True)

# %%
avg_stroke = autos['stroke'].astype('float').mean(axis=0)
print("Promedio de stroke:",avg_stroke)
# Out:
# Promedio de stroke: 3.255422885572139

# %%
autos["stroke"].replace(np.nan, avg_stroke, inplace=True)
# Out:
# /tmp/ipykernel_5728/3936051192.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   autos["stroke"].replace(np.nan, avg_stroke, inplace=True)

# %%
avg_horsepower = autos['horsepower'].astype('float').mean(axis=0)
print("Promedio de horsepower:",avg_horsepower)
# Out:
# Promedio de horsepower: 104.25615763546799

# %%
autos["horsepower"].replace(np.nan, avg_horsepower, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2756/2974815720.py in <cell line: 0>()
# ----> 1 autos["horsepower"].replace(np.nan, avg_horsepower, inplace=True)
#
# NameError: name 'avg_horsepower' is not defined

# %%
autos['fuel-type'].value_counts()
# Out:
# fuel-type
# gas       185
# diesel     20
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
autos['fuel-type_code'] = le.fit_transform(autos['fuel-type'])

# %%
autos.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  fuel-system  \
# 0  convertible          rwd           front        88.6  ...         mpfi
# 1  convertible          rwd           front        88.6  ...         mpfi
# 2    hatchback          rwd           front        94.5  ...         mpfi
# 3        sedan          fwd           front        99.8  ...         mpfi
# 4        sedan          4wd           front        99.4  ...         mpfi
#
#    bore  stroke  compression-ratio horsepower peak-rpm  city-mpg highway-mpg  \
# 0  3.47    2.68                9.0        111     5000        21          27
# 1  3.47    2.68                9.0        111     5000        21          27
# 2  2.68    3.47                9.0        154     5000        19          26
# 3  3.19     3.4               10.0        102     5500        24          30
# 4  3.19     3.4                8.0        115     5500        18          22
#
#    price fuel-type_code
# 0  13495              1
# 1  16500              1
# 2  16500              1
# 3  13950              1
# 4  17450              1
#
# [5 rows x 27 columns]

# %%
variable_dummy1 = pd.get_dummies(autos["fuel-type"])
variable_dummy1.head()
# Out:
#    diesel   gas
# 0   False  True
# 1   False  True
# 2   False  True
# 3   False  True
# 4   False  True

# %%
mapeo_dicc = {'diesel':0,'gas':1}
autos['fuel-type_map'] = autos["fuel-type"].map(mapeo_dicc)

# %%
autos.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  bore  stroke  \
# 0  convertible          rwd           front        88.6  ...  3.47    2.68
# 1  convertible          rwd           front        88.6  ...  3.47    2.68
# 2    hatchback          rwd           front        94.5  ...  2.68    3.47
# 3        sedan          fwd           front        99.8  ...  3.19     3.4
# 4        sedan          4wd           front        99.4  ...  3.19     3.4
#
#    compression-ratio  horsepower peak-rpm city-mpg  highway-mpg  price  \
# 0                9.0         111     5000       21           27  13495
# 1                9.0         111     5000       21           27  16500
# 2                9.0         154     5000       19           26  16500
# 3               10.0         102     5500       24           30  13950
# 4                8.0         115     5500       18           22  17450
#
#   fuel-type_code fuel-type_map
# 0              1             1
# 1              1             1
# 2              1             1
# 3              1             1
# 4              1             1
#
# [5 rows x 28 columns]

# %%
autos["horsepower"] = autos["horsepower"].replace("?", np.nan)
autos["horsepower"] = pd.to_numeric(autos["horsepower"], errors='coerce')
avg_horsepower = autos['horsepower'].mean(axis=0)
autos["horsepower"] = autos["horsepower"].replace(np.nan, avg_horsepower)
autos["horsepower"] = autos["horsepower"].astype(int, copy=True)

plt.pyplot.hist(autos["horsepower"])
plt.pyplot.xlabel("Caballos de fuerza")
plt.pyplot.ylabel("Cantidad")
plt.pyplot.title("Contenedores horsepower")
# Out:
# Text(0.5, 1.0, 'Contenedores horsepower')
